# %% [markdown]
# ---
# layout: post
# categories: [CSP Sprint Objectives]
# title: 2021 AP CSP MCQ Analysis
# description:  Software Development using Frontend and Backend Technologies
# type: issues
# courses: { csp: {week: 31} }
# comments: true
# ---

# %% [markdown]
# # SCORE + STATS
# ![Image](https://github.com/user-attachments/assets/6ee00157-57d0-422a-b0c4-36fd7795609e)
# ![Image](https://github.com/user-attachments/assets/6d189f6c-d1e5-4dcc-845c-32e721e6da06)

# %% [markdown]
# # TOP 3 MISTAKES
# ![image-2.png](attachment:image-2.png)
# Correct Answer : C
#
# ![image.png](attachment:image.png)
# Correct Answer : C
#
# ![image-3.png](attachment:image-3.png)
# Correct Answer : D
